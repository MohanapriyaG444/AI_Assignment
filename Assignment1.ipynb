# %% [markdown]
# <a href="https://colab.research.google.com/github/MohanapriyaG444/AI_Assignment/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sb 
import math

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-de25be4f-1854-4449-ab43-6cdafa3cc418" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de25be4f-1854-4449-ab43-6cdafa3cc418">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset = pd.read_csv("House Price India.csv")

# %%
dataset.head(2)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                  2.5         3650
# 1  6762810635  42491                   4                  2.5         2920
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# ...

# %%
pd.DataFrame(list(dataset.columns), columns=['Column Name'])
# Out:
#                               Column Name
# 0                                      id
# 1                                    Date
# 2                      number of bedrooms
# 3                     number of bathrooms
# 4                             living area
# 5                                lot area
# 6                        number of floors
# 7                      waterfront present
# 8                         number of views
# 9                  condition of the house
# 10                     grade of the house
# 11  Area of the house(excluding basement)
# 12                   Area of the basement
# 13                             Built Year
# 14                        Renovation Year
# 15                            Postal Code
# 16                              Lattitude
# 17                              Longitude
# 18                      living_area_renov
# 19                         lot_area_renov
# 20               Number of schools nearby
# ...

# %%
dataset.shape
# Out:
# (14620, 23)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %% [markdown]
# # **Univariate analysis**

# %%
sb.countplot(data=dataset, x='number of bedrooms')
plt.show()

# %%
plt.figure(figsize=(15,8))
sb.countplot(data=dataset, x='number of bathrooms')
plt.show()

# %%
sb.countplot(data=dataset, x='number of floors')
plt.show()

# %%
sb.countplot(data=dataset, x='waterfront present')
plt.show()

# %%
sb.countplot(data=dataset, x='number of views')
plt.show()

# %%
sb.countplot(data=dataset, x='condition of the house')
plt.show()

# %%
sb.countplot(data=dataset, x='grade of the house')
plt.show()

# %%
plt.figure(figsize=(15,8))
sb.countplot(data=dataset, x='Distance from the airport')
plt.show()

# %%
sb.histplot(data=dataset, x='Distance from the airport')
plt.show()

# %% [markdown]
# # **Bivariate analysis**

# %%
sb.barplot(data=dataset, x='Number of schools nearby', y='Distance from the airport')
plt.title('Number of schools vs Distance from airport')
plt.show()

# %%
sb.barplot(data=dataset, x='number of bedrooms', y='number of bathrooms')
plt.title('Number of bedrooms vs Number of bathrooms')
plt.show()

# %%
sb.barplot(data=dataset, x='condition of the house', y='grade of the house')
plt.title('Condition of the house vs grade of the house')
plt.show()

# %%
sb.barplot(data=dataset, x='number of views', y='grade of the house')
plt.title('number of views vs grade of the house')
plt.show()

# %%
sb.barplot(data=dataset, x='condition of the house', y='number of views')
plt.title('Condition of the house vs number of views')
plt.show()

# %% [markdown]
# # **Multivariate Analysis**

# %%
sb.lmplot(data=dataset,x='condition of the house',y='Price',hue='number of bedrooms')
plt.show()

# %% [markdown]
# # **Descriptive statistics**

# %%
df=pd.DataFrame(dataset)
print(df)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
print(df.sum())
# Out:
# id                                       9.887244e+13
# Date                                     6.228784e+08
# number of bedrooms                       4.940600e+04
# number of bathrooms                      3.113450e+04
# living area                              3.067660e+07
# lot area                                 2.206638e+08
# number of floors                         2.196450e+04
# waterfront present                       1.120000e+02
# number of views                          3.408000e+03
# condition of the house                   5.015400e+04
# grade of the house                       1.123170e+05
# Area of the house(excluding basement)    2.634208e+07
# Area of the basement                     4.334524e+06
# Built Year                               2.881494e+07
# Renovation Year                          1.329309e+06
# Postal Code                              1.784123e+09
# Lattitude                                7.718314e+05
# ...

# %%
print(df.mean())
# Out:
# id                                       6.762821e+09
# Date                                     4.260454e+04
# number of bedrooms                       3.379343e+00
# number of bathrooms                      2.129583e+00
# living area                              2.098263e+03
# lot area                                 1.509328e+04
# number of floors                         1.502360e+00
# waterfront present                       7.660739e-03
# number of views                          2.331053e-01
# condition of the house                   3.430506e+00
# grade of the house                       7.682421e+00
# Area of the house(excluding basement)    1.801784e+03
# Area of the basement                     2.964791e+02
# Built Year                               1.970926e+03
# Renovation Year                          9.092401e+01
# Postal Code                              1.220331e+05
# Lattitude                                5.279285e+01
# ...

# %%
print(df.std())
# Out:
# id                                         6237.574799
# Date                                         67.347991
# number of bedrooms                            0.938719
# number of bathrooms                           0.769934
# living area                                 928.275721
# lot area                                  37919.621304
# number of floors                              0.540239
# waterfront present                            0.087193
# number of views                               0.766259
# condition of the house                        0.664151
# grade of the house                            1.175033
# Area of the house(excluding basement)       833.809963
# Area of the basement                        448.551409
# Built Year                                   29.493625
# Renovation Year                             416.216661
# Postal Code                                  19.082418
# Lattitude                                     0.137522
# ...

# %%
print(df.count())
# Out:
# id                                       14620
# Date                                     14620
# number of bedrooms                       14620
# number of bathrooms                      14620
# living area                              14620
# lot area                                 14620
# number of floors                         14620
# waterfront present                       14620
# number of views                          14620
# condition of the house                   14620
# grade of the house                       14620
# Area of the house(excluding basement)    14620
# Area of the basement                     14620
# Built Year                               14620
# Renovation Year                          14620
# Postal Code                              14620
# Lattitude                                14620
# Longitude                                14620
# living_area_renov                        14620
# lot_area_renov                           14620
# ...

# %%
print(df.abs())
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
print(df.median())
# Out:
# id                                       6.762821e+09
# Date                                     4.260000e+04
# number of bedrooms                       3.000000e+00
# number of bathrooms                      2.250000e+00
# living area                              1.930000e+03
# lot area                                 7.620000e+03
# number of floors                         1.500000e+00
# waterfront present                       0.000000e+00
# number of views                          0.000000e+00
# condition of the house                   3.000000e+00
# grade of the house                       7.000000e+00
# Area of the house(excluding basement)    1.580000e+03
# Area of the basement                     0.000000e+00
# Built Year                               1.975000e+03
# Renovation Year                          0.000000e+00
# Postal Code                              1.220320e+05
# Lattitude                                5.280640e+01
# ...

# %%
dataset.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# # **Handling the missing values**

# %%
#checking for null values using isnull()
df.isnull()
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0      False  False               False                False        False
# 1      False  False               False                False        False
# 2      False  False               False                False        False
# 3      False  False               False                False        False
# 4      False  False               False                False        False
# ...      ...    ...                 ...                  ...          ...
# 14615  False  False               False                False        False
# 14616  False  False               False                False        False
# 14617  False  False               False                False        False
# 14618  False  False               False                False        False
# 14619  False  False               False                False        False
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
#checking for null values using notnull()
df.notnull()
# Out:
#          id  Date  number of bedrooms  number of bathrooms  living area  \
# 0      True  True                True                 True         True
# 1      True  True                True                 True         True
# 2      True  True                True                 True         True
# 3      True  True                True                 True         True
# 4      True  True                True                 True         True
# ...     ...   ...                 ...                  ...          ...
# 14615  True  True                True                 True         True
# 14616  True  True                True                 True         True
# 14617  True  True                True                 True         True
# 14618  True  True                True                 True         True
# 14619  True  True                True                 True         True
#
#        lot area  number of floors  waterfront present  number of views  \
# ...

# %%
#filling the missing values
df.fillna(0)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
#interpolate missing values
df.interpolate()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
#deleting rows having null values
df.dropna()
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...
